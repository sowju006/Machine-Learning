# %% [markdown]
# # Amazon Orders in India

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:/Users/sowjanya/Desktop/codingrade/Amazon_orders_data.csv')

# %%
df
# Out:
#                 order_no                       order_date       buyer  \
# 0    405-9763961-5211537  Sun, 18 Jul, 2021, 10:38 pm IST         Mr.
# 1    404-3964908-7850720   Tue, 19 Oct, 2021, 6:05 pm IST       Minam
# 2    171-8103182-4289117  Sun, 28 Nov, 2021, 10:20 pm IST  yatipertin
# 3    405-3171677-9557154   Wed, 28 Jul, 2021, 4:06 am IST       aciya
# 4    402-8910771-1215552  Tue, 28 Sept, 2021, 2:50 pm IST     Susmita
# ..                   ...                              ...         ...
# 166  171-2829978-1258758  Mon, 13 Dec, 2021, 11:30 am IST      Shahin
# 167  402-3045457-5360311   Wed, 1 Dec, 2021, 12:18 pm IST  Sharmistha
# 168  408-2260162-8323567    Thu, 9 Dec, 2021, 6:55 pm IST    shashank
# 169  403-5664951-8941100  Wed, 23 Feb, 2022, 12:43 am IST      Jayeta
# 170  402-4845680-8041921   Sun, 26 Dec, 2021, 6:21 pm IST       Varun
#
#         ship_city         ship_state                 sku  \
# 0     CHANDIGARH,         CHANDIGARH  SKU:  2X-3C0F-KNJE
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 171 entries, 0 to 170
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_no      171 non-null    object
#  1   order_date    171 non-null    object
#  2   buyer         171 non-null    object
#  3   ship_city     171 non-null    object
#  4   ship_state    171 non-null    object
#  5   sku           171 non-null    object
#  6   description   171 non-null    object
#  7   quantity      171 non-null    int64
#  8   item_total    153 non-null    object
#  9   shipping_fee  145 non-null    object
#  10  cod           47 non-null     object
#  11  order_status  171 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 16.2+ KB

# %%
df.isnull().sum()
# Out:
# order_no          0
# order_date        0
# buyer             0
# ship_city         0
# ship_state        0
# sku               0
# description       0
# quantity          0
# item_total       18
# shipping_fee     26
# cod             124
# order_status      0
# dtype: int64

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# order_no        0
# order_date      0
# buyer           0
# ship_city       0
# ship_state      0
# sku             0
# description     0
# quantity        0
# item_total      0
# shipping_fee    0
# cod             0
# order_status    0
# dtype: int64

# %%
df
# Out:
#                 order_no                       order_date            buyer  \
# 7    405-8702211-4054722  Wed, 29 Sept, 2021, 2:55 pm IST          Pratima
# 12   402-5321389-8685152  Sat, 16 Oct, 2021, 10:11 am IST          Blessan
# 16   405-6918787-5602743   Wed, 25 Aug, 2021, 7:48 am IST            Mosin
# 19   402-8678022-3083562   Fri, 1 Oct, 2021, 11:34 pm IST            Heena
# 25   402-2054361-4513137  Mon, 6 Sept, 2021, 12:46 pm IST           Ramesh
# 27   404-9680499-3084319   Fri, 29 Oct, 2021, 6:58 am IST          Manisha
# 28   406-3518585-4093925  Mon, 20 Sept, 2021, 6:41 pm IST                m
# 32   407-0864859-8033111   Fri, 29 Oct, 2021, 2:19 pm IST       Deepshikha
# 34   403-0713090-0169940   Thu, 28 Oct, 2021, 3:54 pm IST           sayani
# 38   407-0539421-4069143   Mon, 1 Nov, 2021, 11:33 am IST          Parmeet
# 45   404-6735919-2773947  Sun, 31 Oct, 2021, 11:28 pm IST  swagata13051978
# ...

# %%
df.drop(['sku'],axis=1,inplace=True)
df
# Out:
#                 order_no                       order_date            buyer  \
# 7    405-8702211-4054722  Wed, 29 Sept, 2021, 2:55 pm IST          Pratima
# 12   402-5321389-8685152  Sat, 16 Oct, 2021, 10:11 am IST          Blessan
# 16   405-6918787-5602743   Wed, 25 Aug, 2021, 7:48 am IST            Mosin
# 19   402-8678022-3083562   Fri, 1 Oct, 2021, 11:34 pm IST            Heena
# 25   402-2054361-4513137  Mon, 6 Sept, 2021, 12:46 pm IST           Ramesh
# 27   404-9680499-3084319   Fri, 29 Oct, 2021, 6:58 am IST          Manisha
# 28   406-3518585-4093925  Mon, 20 Sept, 2021, 6:41 pm IST                m
# 32   407-0864859-8033111   Fri, 29 Oct, 2021, 2:19 pm IST       Deepshikha
# 34   403-0713090-0169940   Thu, 28 Oct, 2021, 3:54 pm IST           sayani
# 38   407-0539421-4069143   Mon, 1 Nov, 2021, 11:33 am IST          Parmeet
# 45   404-6735919-2773947  Sun, 31 Oct, 2021, 11:28 pm IST  swagata13051978
# ...

# %%
df=df.replace(['\?'," "],"",regex=True)
df
# Out:
#                 order_no                 order_date            buyer  \
# 7    405-8702211-4054722  Wed,29Sept,2021,2:55pmIST          Pratima
# 12   402-5321389-8685152  Sat,16Oct,2021,10:11amIST          Blessan
# 16   405-6918787-5602743   Wed,25Aug,2021,7:48amIST            Mosin
# 19   402-8678022-3083562   Fri,1Oct,2021,11:34pmIST            Heena
# 25   402-2054361-4513137  Mon,6Sept,2021,12:46pmIST           Ramesh
# 27   404-9680499-3084319   Fri,29Oct,2021,6:58amIST          Manisha
# 28   406-3518585-4093925  Mon,20Sept,2021,6:41pmIST                m
# 32   407-0864859-8033111   Fri,29Oct,2021,2:19pmIST       Deepshikha
# 34   403-0713090-0169940   Thu,28Oct,2021,3:54pmIST           sayani
# 38   407-0539421-4069143   Mon,1Nov,2021,11:33amIST          Parmeet
# 45   404-6735919-2773947  Sun,31Oct,2021,11:28pmIST  swagata13051978
# 50   403-1631300-1893901   Sat,13Nov,2021,4:47pmIST        saravanan
# 53   406-5723826-0192341   Fri,22Oct,2021,2:57pmIST           Sailee
# ...

# %%
df=df.replace(['\,'," "],"",regex=True)
df
# Out:
#                 order_no              order_date            buyer  \
# 7    405-8702211-4054722  Wed29Sept20212:55pmIST          Pratima
# 12   402-5321389-8685152  Sat16Oct202110:11amIST          Blessan
# 16   405-6918787-5602743   Wed25Aug20217:48amIST            Mosin
# 19   402-8678022-3083562   Fri1Oct202111:34pmIST            Heena
# 25   402-2054361-4513137  Mon6Sept202112:46pmIST           Ramesh
# 27   404-9680499-3084319   Fri29Oct20216:58amIST          Manisha
# 28   406-3518585-4093925  Mon20Sept20216:41pmIST                m
# 32   407-0864859-8033111   Fri29Oct20212:19pmIST       Deepshikha
# 34   403-0713090-0169940   Thu28Oct20213:54pmIST           sayani
# 38   407-0539421-4069143   Mon1Nov202111:33amIST          Parmeet
# 45   404-6735919-2773947  Sun31Oct202111:28pmIST  swagata13051978
# 50   403-1631300-1893901   Sat13Nov20214:47pmIST        saravanan
# 53   406-5723826-0192341   Fri22Oct20212:57pmIST           Sailee
# ...

# %%
df['item_total']=pd.to_numeric(df['item_total'],errors='coerce')
df['item_total'].dtype
# Out:
# dtype('float64')

# %%
df['shipping_fee']=pd.to_numeric(df['shipping_fee'],errors='coerce')
df['shipping_fee'].dtype
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 33 entries, 7 to 169
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_no      33 non-null     object
#  1   order_date    33 non-null     object
#  2   buyer         33 non-null     object
#  3   ship_city     33 non-null     object
#  4   ship_state    33 non-null     object
#  5   description   33 non-null     object
#  6   quantity      33 non-null     int64
#  7   item_total    33 non-null     float64
#  8   shipping_fee  33 non-null     float64
#  9   cod           33 non-null     object
#  10  order_status  33 non-null     object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 3.1+ KB

# %%
df
# Out:
#                 order_no              order_date            buyer  \
# 7    405-8702211-4054722  Wed29Sept20212:55pmIST          Pratima
# 12   402-5321389-8685152  Sat16Oct202110:11amIST          Blessan
# 16   405-6918787-5602743   Wed25Aug20217:48amIST            Mosin
# 19   402-8678022-3083562   Fri1Oct202111:34pmIST            Heena
# 25   402-2054361-4513137  Mon6Sept202112:46pmIST           Ramesh
# 27   404-9680499-3084319   Fri29Oct20216:58amIST          Manisha
# 28   406-3518585-4093925  Mon20Sept20216:41pmIST                m
# 32   407-0864859-8033111   Fri29Oct20212:19pmIST       Deepshikha
# 34   403-0713090-0169940   Thu28Oct20213:54pmIST           sayani
# 38   407-0539421-4069143   Mon1Nov202111:33amIST          Parmeet
# 45   404-6735919-2773947  Sun31Oct202111:28pmIST  swagata13051978
# 50   403-1631300-1893901   Sat13Nov20214:47pmIST        saravanan
# 53   406-5723826-0192341   Fri22Oct20212:57pmIST           Sailee
# ...

# %%
df.describe()
# Out:
#         quantity   item_total  shipping_fee
# count  33.000000    33.000000     33.000000
# mean    1.060606   549.848485     83.029091
# std     0.348155   322.822525     21.500255
# min     1.000000   250.000000     47.200000
# 25%     1.000000   399.000000     81.420000
# 50%     1.000000   449.000000     84.960000
# 75%     1.000000   549.000000     84.960000
# max     3.000000  1499.000000    178.180000

# %%
df.var()
# Out:
# quantity             0.121212
# item_total      104214.382576
# shipping_fee       462.260977
# dtype: float64

# %%
df.mean()
# Out:
# quantity          1.060606
# item_total      549.848485
# shipping_fee     83.029091
# dtype: float64

# %%
df.median()
# Out:
# quantity          1.00
# item_total      449.00
# shipping_fee     84.96
# dtype: float64

# %%
df.std()
# Out:
# quantity          0.348155
# item_total      322.822525
# shipping_fee     21.500255
# dtype: float64

# %%
df.count()
# Out:
# order_no        33
# order_date      33
# buyer           33
# ship_city       33
# ship_state      33
# description     33
# quantity        33
# item_total      33
# shipping_fee    33
# cod             33
# order_status    33
# dtype: int64

# %%
df.min()
# Out:
# order_no                                      171-1659664-7877932
# order_date                                  Fri10Dec20215:53pmIST
# buyer                                                       Aarti
# ship_city                                                  AMROHA
# ship_state                                                  ASSAM
# description     100%LeatherElephantShapedPiggyCoinBank|BlockPr...
# quantity                                                        1
# item_total                                                  250.0
# shipping_fee                                                 47.2
# cod                                                CashOnDelivery
# order_status                                     Deliveredtobuyer
# dtype: object

# %%
df.max()
# Out:
# order_no                                      407-6814126-3628337
# order_date                                  Wed8Dec202111:54pmIST
# buyer                                             swagata13051978
# ship_city                                                   Surat
# ship_state                                             WESTBENGAL
# description     Women'sSetof5MulticolorPureLeatherSingleLipsti...
# quantity                                                        3
# item_total                                                 1499.0
# shipping_fee                                               178.18
# cod                                                CashOnDelivery
# order_status                                     Deliveredtobuyer
# dtype: object

# %%
plt.bar(Amazon['buyer'],Amazon['item_total'])
plt.title('Amazon orders')
plt.ylabel('item_total')
plt.gcf().set_size_inches(8,8)
plt.xticks(rotation=90)
plt.show()

# %%
display(df['ship_city'].value_counts())
# Out:
# MUMBAI                5
# NEWDELHI              3
# KOLKATA               3
# BAREILLY              1
# CHENNAI               1
# KodambakkamChennai    1
# AMROHA                1
# PUNJAB                1
# NAVIMUMBAI            1
# SIWAN                 1
# SECUNDERABAD          1
# CHANDIGARH            1
# JODHPUR               1
# GUWAHATI              1
# Surat                 1
# PALAI                 1
# COONOOR               1
# KARAIKKUDI            1
# SILCHAR               1
# JAMMU                 1
# HYDERABAD             1
# PUNEpune              1
# JALESWAR              1
# MAHALINGPUR           1
# BILIMORA              1
# Name: ship_city, dtype: int64

# %%
display(df['ship_state'].value_counts())
# Out:
# MAHARASHTRA      7
# TAMILNADU        4
# DELHI            3
# WESTBENGAL       3
# UTTARPRADESH     2
# TELANGANA        2
# ASSAM            2
# GUJARAT          2
# KARNATAKA        1
# ODISHA           1
# JAMMU&KASHMIR    1
# KERALA           1
# RAJASTHAN        1
# CHANDIGARH       1
# BIHAR            1
# MOHALI           1
# Name: ship_state, dtype: int64

# %%
ship_state=df['ship_state'].value_counts()
buyer=['MAHARASHTRA','TAMILNADU','DELHI','WESTBENGAL','UTTARPRADESH','TELANGANA','ASSAM','GUJARAT','KARNATAKA','ODISHA','JAMMU&KASHMIR','KERALA','RAJASTHAN','CHANDIGARH','BIHAR','MOHALI']
plt.gcf().set_size_inches(8,8)
plt.pie(ship_state,labels=buyer,autopct='%1.1f%%',wedgeprops={'edgecolor':'black'})
plt.title('Amazon orders in India')
plt.show()

# %%
fig,ax=plt.subplots(1,1)
a=np.array([4,3,3,2,2,2,2,1,1,1,1,1,1,1,1])
ax.hist(a,bins=[1,2,3,4,5])
ax.set_title('Amazon orders in India')
ax.set_xticks([1,2,3,4,5])
ax.set_xlabel('ship_state')
ax.set_ylabel('item_total')
plt.show()
